# %%
# !python run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/ \
  --data_path cd10mm.csv \
  --model_id your_model_run_id \
  --model TimeXer \
  --data your_dataset_name \
  --features M \
  --seq_len 2000 \
  --label_len 1000 \
  --pred_len 1000 \
  --e_layers 2 \
  --factor 3 \
  --enc_in 5 \
  --dec_in 5 \
  --c_out 5 \
  --d_model 512 \
  --d_ff 512 \
  --batch_size 128 \
  --des 'your_experiment_description' \
  --itr 1 \
  --patch_len 20 \
  --target 'AI1-01'
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           your_model_run_id   Model:              TimeXer
#
# Data Loader
#   Data:               your_dataset_name   Root Path:          ./dataset/
#   Data Path:          cd10mm.csv          Features:           M
#   Target:             'AI1-01'            Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            2000                Label Len:          1000
#   Pred Len:           1000                Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             5                   Dec In:             5
#   C Out:              5                   d model:            512
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               512
# ...

# %%
# !python run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/ \
  --data_path cd10mm.csv \
  --model_id your_model_run_id \
  --model TimeXer \
  --data your_dataset_name \
  --features M \
  --seq_len 2000 \
  --label_len 1000 \
  --pred_len 1000 \
  --e_layers 2 \
  --factor 3 \
  --enc_in 5 \
  --dec_in 5 \
  --c_out 5 \
  --d_model 512 \
  --d_ff 512 \
  --batch_size 128 \
  --des 'your_experiment_description' \
  --itr 1 \
  --patch_len 20 \
  --target 'AI1-04'
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           your_model_run_id   Model:              TimeXer
#
# Data Loader
#   Data:               your_dataset_name   Root Path:          ./dataset/
#   Data Path:          cd10mm.csv          Features:           M
#   Target:             'AI1-04'            Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            2000                Label Len:          1000
#   Pred Len:           1000                Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             5                   Dec In:             5
#   C Out:              5                   d model:            512
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               512
# ...

# %%
# !python run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/ \
  --data_path cd10mm.csv \
  --model_id your_model_run_id \
  --model PatchTST \
  --data your_dataset_name \
  --features M \
  --seq_len 2000 \
  --label_len 1000 \
  --pred_len 1000 \
  --e_layers 2 \
  --factor 3 \
  --enc_in 5 \
  --dec_in 5 \
  --c_out 5 \
  --d_model 512 \
  --d_ff 512 \
  --batch_size 128 \
  --des 'your_experiment_description-TST' \
  --itr 1 \
  --patch_len 20 \
  --target 'AI1-01'
